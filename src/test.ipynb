# %%
from itertools import islice
from thinkflow_rdt.adapters.bridge import BridgeStandardizedIterableDataset

# %%
ds = BridgeStandardizedIterableDataset(
    "../dataset/mock_dataset/bridge_dataset/bridge_subset",
    normalize_actions=True
)

# %%
iterator = iter(ds)

# %%
sample = next(iterator)

# %%
sample.keys()
# Out:
# dict_keys(['dataset_id', 'episode_id', 'step_idx', 'instruction', 'images', 'image_mask', 'state', 'state_mask', 'actions', 'actions_mask'])

# %%
sample["actions"].shape
# Out:
# (32, 7)

# %%
sample["images"]['primary']
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>
