# %%
import tensorflow_datasets as tfds

# %%
ds_dir = r"data"

# %%
builder = tfds.builder_from_directory(ds_dir)

# %%
print(builder.info)
# Out:
# tfds.core.DatasetInfo(
#     name='bc_z',
#     full_name='bc_z/1.0.0',
#     description="""
#     BC-Z robot episodes from BC-Z paper (https://sites.google.com/view/bc-z/home).
#     """,
#     homepage='https://sites.google.com/view/bc-z/home',
#     data_dir='data',
#     file_format=array_record,
#     download_size=Unknown size,
#     dataset_size=79.69 GiB,
#     features=FeaturesDict({
#         'episode_id': string,
#         'steps': Dataset({
#             'action': FeaturesDict({
#                 'future/axis_angle_residual': Tensor(shape=(30,), dtype=float32, description=The next 10 actions for the rotation. Each action is a 3D delta to add to the current axis angle.),
#                 'future/target_close': Tensor(shape=(10,), dtype=int64, description=The next 10 actions for the gripper. Each action is the value the gripper closure should be changed to (notably it is *not* a delta.)),
# ...

# %%
train_src = builder.as_data_source(split="train")
# Out:
# ***************************************************************
# Failed to import ArrayRecord. This probably means that you are running on macOS or Windows. ArrayRecord currently does not work for your infrastructure, because it uses Python bindings in C++. We are actively working on this issue. Thanks for your understanding.
# ***************************************************************
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 train_src = builder.as_data_source(split="train")
#
# File c:\Users\rshre\thinkflow_rdt1b_lora\.venv\Lib\site-packages\tensorflow_datasets\core\logging\__init__.py:176, in _FunctionDecorator.__call__(self, function, instance, args, kwargs)
#     174 metadata = self._start_call()
#     175 try:
# --> 176   return function(*args, **kwargs)
#     177 except Exception:
#     178   metadata.mark_error()
#
# ...

# %%
for example in tfds.as_numpy(train_ds.take(1)):
    print(example.keys())
    print(example['episode_id'])
